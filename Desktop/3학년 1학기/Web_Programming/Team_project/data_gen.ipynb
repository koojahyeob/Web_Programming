# %%
import json
import random
from faker import Faker

fake = Faker('ko_KR')

# 식당 유형
restaurant_types = ['한식', '일식', '중식', '양식', '프랑스식', '이탈리아 음식','아메리칸 음식','퓨전음식', '아시아음식']

# 메뉴 예시
menus = {
    '한식': [
        {'name': '김치찌개', 'price': '8000원'},
        {'name': '비빔밥', 'price': '9000원'},
        {'name': '된장찌개', 'price': '7000원'},
        {'name': '갈비탕', 'price': '12000원'}
    ],
    '일식': [
        {'name': '초밥', 'price': '15000원'},
        {'name': '라멘', 'price': '12000원'},
        {'name': '돈부리', 'price': '11000원'},
        {'name': '사케동', 'price': '13000원'}
    ],
    '중식': [
        {'name': '짜장면', 'price': '5000원'},
        {'name': '짬뽕', 'price': '6000원'},
        {'name': '탕수육', 'price': '15000원'},
        {'name': '마파두부', 'price': '8000원'}
    ],
    '양식': [
        {'name': '스테이크', 'price': '20000원'},
        {'name': '파스타', 'price': '12000원'},
        {'name': '리조또', 'price': '10000원'},
        {'name': '햄버거', 'price': '8000원'}
    ],
    '프랑스식': [
        {'name': '에스카르고', 'price': '18000원'},
        {'name': '라따뚜이', 'price': '16000원'},
        {'name': '부야베스', 'price': '22000원'},
        {'name': '크림 브륄레', 'price': '9000원'}
    ],
    '이탈리아 음식': [
        {'name': '마르게리타 피자', 'price': '15000원'},
        {'name': '페투치니 알프레도', 'price': '13500원'},
        {'name': '티라미수', 'price': '7000원'},
        {'name': '오소 부코', 'price': '24000원'}
    ],
    '아메리칸 음식': [
        {'name': '바비큐 리브', 'price': '22000원'},
        {'name': '치즈버거', 'price': '10000원'},
        {'name': '콥 샐러드', 'price': '9000원'},
        {'name': '클램 차우더', 'price': '12000원'}
    ],
    '퓨전음식': [
        {'name': '김치 파스타', 'price': '11000원'},
        {'name': '커리 우동', 'price': '9000원'},
        {'name': '멕시칸 삼겹살', 'price': '15000원'},
        {'name': '토마토 탕수육', 'price': '13000원'}
    ],
    '아시아음식': [
        {'name': '팟타이', 'price': '12000원'},
        {'name': '불고기 바오', 'price': '3000원'},
        {'name': '치킨 커리', 'price': '10000원'},
        {'name': '샤오롱바오', 'price': '8000원'}
    ]
}

# 리뷰 생성 함수
def generate_reviews():
    return [
        {
            "author": fake.name(),
            "date": fake.date_this_year().isoformat(),
            "rating": random.uniform(3.0, 5.0),
            "comment": fake.sentence()
        } for _ in range(random.randint(1, 5))
    ]

# 100개의 식당 정보 생성
restaurants = []
for i in range(100):
    type = random.choice(restaurant_types)
    restaurant = {
        "id": str(i + 1),
        "name": fake.company() + " " + type,
        "location": fake.street_address(),
        "priceRange": random.choice(["최저가", "저가", "중간", "고가", "최고가"]),
        "rating": round(random.uniform(1.0, 5.0), 1),
        "menus": random.sample(menus[type], 2),
        "businessHours": "오전 10시 - 오후 10시",
        "reservations": [],
        "additionalServices": random.sample(["배달 가능", "포장 가능", "예약 가능", "주차 가능"], 2),
        "seatingCapacity": random.randint(10, 100),
        "contact": {
            "phone": fake.phone_number(),
            "email": fake.email()
        },
        "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
        "website": fake.url(),
        "reviews": generate_reviews()
    }
    restaurants.append(restaurant)

# JSON 형식으로 출력
json_data = json.dumps(restaurants, indent=2, ensure_ascii=False)
print(json_data)
# Out:
# [
#   {
#     "id": "1",
#     "name": "유한회사 곽민한 아메리칸 음식",
#     "location": "전라남도 고양시 일산서구 선릉15거리 (보람이김마을)",
#     "priceRange": "중간",
#     "rating": 1.5,
#     "menus": [
#       {
#         "name": "클램 차우더",
#         "price": "12000원"
#       },
#       {
#         "name": "콥 샐러드",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 11,
#     "contact": {
#       "phone": "042-202-8423",
#       "email": "gimmisug@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.jusighoesa.org/",
#     "reviews": [
#       {
#         "author": "이영호",
#         "date": "2024-04-22",
#         "rating": 4.842165833120627,
#         "comment": "Nesciunt ex magnam veritatis."
#       },
#       {
#         "author": "곽영수",
#         "date": "2024-02-13",
#         "rating": 3.734639597333625,
#         "comment": "Corrupti nobis laudantium corporis vel ut voluptatum."
#       },
#       {
#         "author": "박건우",
#         "date": "2024-02-05",
#         "rating": 4.034914605800492,
#         "comment": "Aspernatur odit nemo impedit deserunt neque iure."
#       },
#       {
#         "author": "윤상철",
#         "date": "2024-03-27",
#         "rating": 4.336785042320076,
#         "comment": "Sapiente quae occaecati voluptatem."
#       }
#     ]
#   },
#   {
#     "id": "2",
#     "name": "(주) 엄 프랑스식",
#     "location": "세종특별자치시 남구 삼성960길 (영수이마을)",
#     "priceRange": "중간",
#     "rating": 3.5,
#     "menus": [
#       {
#         "name": "라따뚜이",
#         "price": "16000원"
#       },
#       {
#         "name": "에스카르고",
#         "price": "18000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 95,
#     "contact": {
#       "phone": "054-566-9463",
#       "email": "seonghoi@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.baggimyun.com/",
#     "reviews": [
#       {
#         "author": "윤상철",
#         "date": "2024-04-04",
#         "rating": 3.7269872872346674,
#         "comment": "Ab in nostrum eum eius."
#       },
#       {
#         "author": "박춘자",
#         "date": "2024-01-13",
#         "rating": 3.221146378519391,
#         "comment": "Vel tempore praesentium vero quasi autem."
#       },
#       {
#         "author": "김상호",
#         "date": "2024-01-28",
#         "rating": 3.28202977454094,
#         "comment": "At repellat eligendi."
#       }
#     ]
#   },
#   {
#     "id": "3",
#     "name": "(주) 장 퓨전음식",
#     "location": "경상북도 삼척시 도산대2가 (성진최마을)",
#     "priceRange": "최저가",
#     "rating": 1.5,
#     "menus": [
#       {
#         "name": "멕시칸 삼겹살",
#         "price": "15000원"
#       },
#       {
#         "name": "김치 파스타",
#         "price": "11000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 57,
#     "contact": {
#       "phone": "018-709-7857",
#       "email": "imisug@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.ju.net/",
#     "reviews": [
#       {
#         "author": "김지민",
#         "date": "2024-01-03",
#         "rating": 3.7252964639969943,
#         "comment": "Odio consequuntur rem in vitae deleniti."
#       }
#     ]
#   },
#   {
#     "id": "4",
#     "name": "주식회사 유 양식",
#     "location": "전라남도 고양시 덕양구 영동대2로",
#     "priceRange": "최저가",
#     "rating": 4.2,
#     "menus": [
#       {
#         "name": "파스타",
#         "price": "12000원"
#       },
#       {
#         "name": "스테이크",
#         "price": "20000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 10,
#     "contact": {
#       "phone": "055-651-1466",
#       "email": "minseog88@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.yuhanhoesa.net/",
#     "reviews": [
#       {
#         "author": "김동현",
#         "date": "2024-01-15",
#         "rating": 3.254204305604989,
#         "comment": "Atque molestiae vero reiciendis quaerat tempore soluta deserunt."
#       },
#       {
#         "author": "오정식",
#         "date": "2024-04-12",
#         "rating": 3.794495759701662,
#         "comment": "Voluptate eius aliquam."
#       }
#     ]
#   },
#   {
#     "id": "5",
#     "name": "박이 일식",
#     "location": "경상남도 광명시 오금8가 (주원김읍)",
#     "priceRange": "저가",
#     "rating": 3.1,
#     "menus": [
#       {
#         "name": "라멘",
#         "price": "12000원"
#       },
#       {
#         "name": "돈부리",
#         "price": "11000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 25,
#     "contact": {
#       "phone": "054-712-6078",
#       "email": "dohyeon87@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://hongi.com/",
#     "reviews": [
#       {
#         "author": "양현숙",
#         "date": "2024-02-09",
#         "rating": 3.6230819504479825,
#         "comment": "Deleniti cupiditate magni corrupti."
#       }
#     ]
#   },
#   {
#     "id": "6",
#     "name": "(유) 김 일식",
#     "location": "경기도 고양시 일산동구 언주가",
#     "priceRange": "저가",
#     "rating": 4.6,
#     "menus": [
#       {
#         "name": "사케동",
#         "price": "13000원"
#       },
#       {
#         "name": "초밥",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 68,
#     "contact": {
#       "phone": "010-9711-9121",
#       "email": "eunyeongo@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.bagison.com/",
#     "reviews": [
#       {
#         "author": "나주원",
#         "date": "2024-02-26",
#         "rating": 3.8227322644667647,
#         "comment": "Deleniti saepe autem ratione rerum dolor veritatis."
#       },
#       {
#         "author": "엄미숙",
#         "date": "2024-04-24",
#         "rating": 4.632945798433084,
#         "comment": "Totam quae iusto voluptatem a veritatis dolorum."
#       },
#       {
#         "author": "김승현",
#         "date": "2024-03-19",
#         "rating": 4.376933844636759,
#         "comment": "Corporis nobis saepe quae error porro."
#       },
#       {
#         "author": "이광수",
#         "date": "2024-03-12",
#         "rating": 3.485849279640022,
#         "comment": "Reiciendis cum quas magnam laboriosam error."
#       }
#     ]
#   },
#   {
#     "id": "7",
#     "name": "박김양 프랑스식",
#     "location": "충청남도 보은군 선릉거리 (정웅이읍)",
#     "priceRange": "최저가",
#     "rating": 2.7,
#     "menus": [
#       {
#         "name": "라따뚜이",
#         "price": "16000원"
#       },
#       {
#         "name": "에스카르고",
#         "price": "18000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 64,
#     "contact": {
#       "phone": "044-819-0666",
#       "email": "seongho59@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://yuhanhoesa.com/",
#     "reviews": [
#       {
#         "author": "이영자",
#         "date": "2024-03-08",
#         "rating": 4.884996664076569,
#         "comment": "Est reiciendis sequi itaque a nisi ut."
#       },
#       {
#         "author": "최지아",
#         "date": "2024-01-22",
#         "rating": 4.723984999345655,
#         "comment": "Exercitationem ducimus quos facilis tempora tempore."
#       },
#       {
#         "author": "배명숙",
#         "date": "2024-01-01",
#         "rating": 4.71576184735634,
#         "comment": "Cum ullam saepe architecto qui debitis eos."
#       },
#       {
#         "author": "박지훈",
#         "date": "2024-02-04",
#         "rating": 3.9089515609012526,
#         "comment": "Occaecati beatae ex libero eveniet quis excepturi."
#       }
#     ]
#   },
#   {
#     "id": "8",
#     "name": "(유) 김박이 퓨전음식",
#     "location": "충청남도 과천시 언주가 (은영박송리)",
#     "priceRange": "저가",
#     "rating": 1.8,
#     "menus": [
#       {
#         "name": "김치 파스타",
#         "price": "11000원"
#       },
#       {
#         "name": "커리 우동",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 61,
#     "contact": {
#       "phone": "063-137-3153",
#       "email": "seohyeon41@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.minibag.kr/",
#     "reviews": [
#       {
#         "author": "구성훈",
#         "date": "2024-02-23",
#         "rating": 4.795250366258973,
#         "comment": "Molestiae porro minus est minima enim quaerat."
#       },
#       {
#         "author": "오진우",
#         "date": "2024-05-01",
#         "rating": 4.789412287125288,
#         "comment": "Totam eaque eligendi."
#       },
#       {
#         "author": "배주원",
#         "date": "2024-01-26",
#         "rating": 4.489755724260173,
#         "comment": "Illo recusandae tenetur ipsam modi consequuntur eaque."
#       },
#       {
#         "author": "김영환",
#         "date": "2024-03-22",
#         "rating": 3.345002646519247,
#         "comment": "Repellat aut ex porro sint officia ipsum voluptatum."
#       }
#     ]
#   },
#   {
#     "id": "9",
#     "name": "윤곽이 중식",
#     "location": "대전광역시 강북구 역삼로",
#     "priceRange": "중간",
#     "rating": 1.8,
#     "menus": [
#       {
#         "name": "마파두부",
#         "price": "8000원"
#       },
#       {
#         "name": "탕수육",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 30,
#     "contact": {
#       "phone": "062-633-3640",
#       "email": "jungsugim@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.ju.net/",
#     "reviews": [
#       {
#         "author": "홍준영",
#         "date": "2024-02-01",
#         "rating": 3.3162945869893488,
#         "comment": "Id accusamus quis nam culpa labore molestiae."
#       },
#       {
#         "author": "최정숙",
#         "date": "2024-02-20",
#         "rating": 3.1112472167462473,
#         "comment": "Minima sequi explicabo."
#       },
#       {
#         "author": "이지후",
#         "date": "2024-03-20",
#         "rating": 3.8446614191602353,
#         "comment": "Mollitia fugiat amet labore nam magnam eveniet."
#       }
#     ]
#   },
#   {
#     "id": "10",
#     "name": "김김 한식",
#     "location": "세종특별자치시 강서구 개포길 (시우김리)",
#     "priceRange": "고가",
#     "rating": 4.9,
#     "menus": [
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       },
#       {
#         "name": "된장찌개",
#         "price": "7000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 82,
#     "contact": {
#       "phone": "062-359-4558",
#       "email": "junyeong59@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://ju.com/",
#     "reviews": [
#       {
#         "author": "이정훈",
#         "date": "2024-02-16",
#         "rating": 3.523123296912418,
#         "comment": "Cumque repellendus tenetur vitae velit."
#       },
#       {
#         "author": "박건우",
#         "date": "2024-01-23",
#         "rating": 3.3580927645706,
#         "comment": "Enim veritatis nesciunt quod sint accusantium mollitia."
#       },
#       {
#         "author": "강영순",
#         "date": "2024-04-29",
#         "rating": 3.5275962426415237,
#         "comment": "Fugit et odio nam quam."
#       },
#       {
#         "author": "장수진",
#         "date": "2024-04-05",
#         "rating": 4.291991905392804,
#         "comment": "Dolorem saepe saepe temporibus mollitia voluptate fuga iure."
#       }
#     ]
#   },
#   {
#     "id": "11",
#     "name": "장윤김 퓨전음식",
#     "location": "충청남도 하남시 오금5거리",
#     "priceRange": "중간",
#     "rating": 3.0,
#     "menus": [
#       {
#         "name": "토마토 탕수육",
#         "price": "13000원"
#       },
#       {
#         "name": "멕시칸 삼겹살",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 43,
#     "contact": {
#       "phone": "063-937-9277",
#       "email": "minjae83@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://jusighoesa.kr/",
#     "reviews": [
#       {
#         "author": "김승민",
#         "date": "2024-03-23",
#         "rating": 3.9626648597485583,
#         "comment": "Quibusdam architecto similique ipsam quia."
#       },
#       {
#         "author": "조정훈",
#         "date": "2024-04-21",
#         "rating": 3.9238692349310584,
#         "comment": "Eligendi cupiditate qui."
#       },
#       {
#         "author": "배은서",
#         "date": "2024-04-04",
#         "rating": 3.545575109946146,
#         "comment": "Accusantium natus nam eum eligendi excepturi saepe pariatur."
#       }
#     ]
#   },
#   {
#     "id": "12",
#     "name": "김장 프랑스식",
#     "location": "전라남도 군포시 서초중앙길 (상훈김김동)",
#     "priceRange": "고가",
#     "rating": 1.9,
#     "menus": [
#       {
#         "name": "라따뚜이",
#         "price": "16000원"
#       },
#       {
#         "name": "부야베스",
#         "price": "22000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 58,
#     "contact": {
#       "phone": "033-316-2609",
#       "email": "yeonghyigim@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://jeongweon.net/",
#     "reviews": [
#       {
#         "author": "박재현",
#         "date": "2024-03-27",
#         "rating": 3.833757666693221,
#         "comment": "Vero quos repudiandae necessitatibus dignissimos ipsam."
#       },
#       {
#         "author": "김승현",
#         "date": "2024-03-02",
#         "rating": 4.150992516201939,
#         "comment": "Suscipit porro vero rerum recusandae facere minima."
#       },
#       {
#         "author": "김시우",
#         "date": "2024-03-12",
#         "rating": 4.240252367271795,
#         "comment": "Atque repudiandae cum sapiente labore eos exercitationem."
#       },
#       {
#         "author": "최성훈",
#         "date": "2024-04-07",
#         "rating": 4.18861754447542,
#         "comment": "Eveniet dolore velit distinctio quisquam asperiores."
#       }
#     ]
#   },
#   {
#     "id": "13",
#     "name": "유한회사 박장홍 양식",
#     "location": "전라남도 파주시 양재천74가 (서연김면)",
#     "priceRange": "최저가",
#     "rating": 2.1,
#     "menus": [
#       {
#         "name": "스테이크",
#         "price": "20000원"
#       },
#       {
#         "name": "햄버거",
#         "price": "8000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 45,
#     "contact": {
#       "phone": "041-185-6302",
#       "email": "ggim@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.ju.com/",
#     "reviews": [
#       {
#         "author": "배영철",
#         "date": "2024-02-13",
#         "rating": 3.8605221637455083,
#         "comment": "Aspernatur perspiciatis a placeat."
#       },
#       {
#         "author": "배민수",
#         "date": "2024-04-04",
#         "rating": 4.799505041218192,
#         "comment": "Rem maxime tempore recusandae in excepturi dicta enim."
#       },
#       {
#         "author": "황정희",
#         "date": "2024-03-14",
#         "rating": 3.530462785657785,
#         "comment": "Fuga corrupti tempore."
#       },
#       {
#         "author": "이정식",
#         "date": "2024-01-19",
#         "rating": 3.2055313138153325,
#         "comment": "Laborum ut esse enim rem dicta."
#       },
#       {
#         "author": "강미숙",
#         "date": "2024-02-09",
#         "rating": 3.0985585011485455,
#         "comment": "Ad repellendus assumenda soluta architecto."
#       }
#     ]
#   },
#   {
#     "id": "14",
#     "name": "김김 아메리칸 음식",
#     "location": "부산광역시 은평구 석촌호수로",
#     "priceRange": "최고가",
#     "rating": 3.9,
#     "menus": [
#       {
#         "name": "바비큐 리브",
#         "price": "22000원"
#       },
#       {
#         "name": "클램 차우더",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 50,
#     "contact": {
#       "phone": "016-589-1079",
#       "email": "seohyeonim@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.igimgim.com/",
#     "reviews": [
#       {
#         "author": "김은지",
#         "date": "2024-01-16",
#         "rating": 4.230714370591851,
#         "comment": "Ipsum exercitationem esse repellendus cumque iste."
#       },
#       {
#         "author": "윤현숙",
#         "date": "2024-03-01",
#         "rating": 3.259601402275276,
#         "comment": "Error nam dolore reprehenderit incidunt maxime."
#       },
#       {
#         "author": "박재호",
#         "date": "2024-02-28",
#         "rating": 4.651946505978325,
#         "comment": "Aspernatur consequuntur fuga nesciunt dolorem dolorem aperiam."
#       },
#       {
#         "author": "김은영",
#         "date": "2024-01-15",
#         "rating": 4.156716664518351,
#         "comment": "Deserunt aut at iusto laboriosam ipsum."
#       }
#     ]
#   },
#   {
#     "id": "15",
#     "name": "김오박 한식",
#     "location": "제주특별자치도 의왕시 석촌호수길 (재현이마을)",
#     "priceRange": "최저가",
#     "rating": 2.1,
#     "menus": [
#       {
#         "name": "된장찌개",
#         "price": "7000원"
#       },
#       {
#         "name": "비빔밥",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 14,
#     "contact": {
#       "phone": "062-903-9284",
#       "email": "jeongjai@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.gimgimcoe.com/",
#     "reviews": [
#       {
#         "author": "박서현",
#         "date": "2024-01-24",
#         "rating": 4.901541901323871,
#         "comment": "Vero eius voluptatem qui aliquam totam."
#       },
#       {
#         "author": "류지연",
#         "date": "2024-04-04",
#         "rating": 4.360311124006536,
#         "comment": "Velit exercitationem at fugit ullam iste."
#       }
#     ]
#   },
#   {
#     "id": "16",
#     "name": "문이홍 일식",
#     "location": "경상북도 용인시 기흥구 학동가",
#     "priceRange": "최저가",
#     "rating": 5.0,
#     "menus": [
#       {
#         "name": "초밥",
#         "price": "15000원"
#       },
#       {
#         "name": "사케동",
#         "price": "13000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 14,
#     "contact": {
#       "phone": "063-301-7435",
#       "email": "hanjaehyeon@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.jusighoesa.kr/",
#     "reviews": [
#       {
#         "author": "최지우",
#         "date": "2024-02-05",
#         "rating": 4.331534383606552,
#         "comment": "Explicabo quo minus dolorum at neque ea."
#       }
#     ]
#   },
#   {
#     "id": "17",
#     "name": "(주) 김 아메리칸 음식",
#     "location": "경기도 연천군 백제고분418길 (정수유동)",
#     "priceRange": "저가",
#     "rating": 3.7,
#     "menus": [
#       {
#         "name": "클램 차우더",
#         "price": "12000원"
#       },
#       {
#         "name": "콥 샐러드",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 89,
#     "contact": {
#       "phone": "052-704-3825",
#       "email": "sgim@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://yu.org/",
#     "reviews": [
#       {
#         "author": "김재현",
#         "date": "2024-03-06",
#         "rating": 4.9922568657465245,
#         "comment": "Nostrum possimus magni esse impedit nihil harum."
#       },
#       {
#         "author": "류정희",
#         "date": "2024-02-07",
#         "rating": 4.236546750921259,
#         "comment": "Ipsum officiis eum."
#       }
#     ]
#   },
#   {
#     "id": "18",
#     "name": "유한회사 홍 아메리칸 음식",
#     "location": "경기도 안산시 도산대로",
#     "priceRange": "고가",
#     "rating": 4.1,
#     "menus": [
#       {
#         "name": "치즈버거",
#         "price": "10000원"
#       },
#       {
#         "name": "바비큐 리브",
#         "price": "22000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 49,
#     "contact": {
#       "phone": "052-778-1662",
#       "email": "sangceol34@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.gimi.net/",
#     "reviews": [
#       {
#         "author": "박영식",
#         "date": "2024-02-26",
#         "rating": 3.3337878816047803,
#         "comment": "Accusamus corrupti ea voluptatem blanditiis."
#       }
#     ]
#   },
#   {
#     "id": "19",
#     "name": "전나 중식",
#     "location": "전라남도 파주시 양재천로",
#     "priceRange": "최고가",
#     "rating": 5.0,
#     "menus": [
#       {
#         "name": "짬뽕",
#         "price": "6000원"
#       },
#       {
#         "name": "탕수육",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 50,
#     "contact": {
#       "phone": "051-984-3618",
#       "email": "mmun@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://ju.com/",
#     "reviews": [
#       {
#         "author": "이재현",
#         "date": "2024-04-25",
#         "rating": 4.558000420023852,
#         "comment": "Tenetur fuga excepturi eveniet officia fugit."
#       },
#       {
#         "author": "나보람",
#         "date": "2024-01-15",
#         "rating": 4.499460661020363,
#         "comment": "Corrupti magni ex et fugiat odit."
#       },
#       {
#         "author": "이재현",
#         "date": "2024-01-21",
#         "rating": 4.060322010667176,
#         "comment": "Suscipit quaerat nisi sed maxime numquam esse."
#       },
#       {
#         "author": "김경자",
#         "date": "2024-01-20",
#         "rating": 4.291139345005652,
#         "comment": "Architecto nostrum ratione."
#       }
#     ]
#   },
#   {
#     "id": "20",
#     "name": "김최유 일식",
#     "location": "충청남도 보은군 개포992길 (명숙장리)",
#     "priceRange": "중간",
#     "rating": 4.1,
#     "menus": [
#       {
#         "name": "돈부리",
#         "price": "11000원"
#       },
#       {
#         "name": "초밥",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 32,
#     "contact": {
#       "phone": "043-204-5577",
#       "email": "gyeongsu05@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.igim.kr/",
#     "reviews": [
#       {
#         "author": "박진호",
#         "date": "2024-05-01",
#         "rating": 3.0474127378329605,
#         "comment": "Facilis consequatur voluptatum nesciunt reprehenderit."
#       },
#       {
#         "author": "김명자",
#         "date": "2024-02-13",
#         "rating": 3.0145056858959873,
#         "comment": "Cupiditate velit nemo odit aut eos."
#       }
#     ]
#   },
#   {
#     "id": "21",
#     "name": "(유) 손최박 이탈리아 음식",
#     "location": "경기도 의왕시 역삼길 (준서이읍)",
#     "priceRange": "최저가",
#     "rating": 2.4,
#     "menus": [
#       {
#         "name": "오소 부코",
#         "price": "24000원"
#       },
#       {
#         "name": "티라미수",
#         "price": "7000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 10,
#     "contact": {
#       "phone": "033-550-6041",
#       "email": "eungyeongbaeg@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.yuhanhoesa.com/",
#     "reviews": [
#       {
#         "author": "이영일",
#         "date": "2024-03-15",
#         "rating": 3.792752093835026,
#         "comment": "Excepturi quaerat ut sit incidunt."
#       },
#       {
#         "author": "한지영",
#         "date": "2024-03-13",
#         "rating": 3.1614508376103303,
#         "comment": "Vel ea maxime veniam molestias quas dolorum."
#       },
#       {
#         "author": "심은서",
#         "date": "2024-02-23",
#         "rating": 4.486354125032585,
#         "comment": "Ipsum dolor minima ipsam in voluptatibus reiciendis."
#       },
#       {
#         "author": "우은지",
#         "date": "2024-02-13",
#         "rating": 3.7478845390366717,
#         "comment": "Adipisci consequatur ullam incidunt dolorem voluptates ea."
#       },
#       {
#         "author": "이상훈",
#         "date": "2024-03-20",
#         "rating": 3.994807456627263,
#         "comment": "Nulla impedit dignissimos itaque quis aspernatur."
#       }
#     ]
#   },
#   {
#     "id": "22",
#     "name": "박송이 양식",
#     "location": "세종특별자치시 은평구 역삼20가",
#     "priceRange": "최고가",
#     "rating": 2.0,
#     "menus": [
#       {
#         "name": "리조또",
#         "price": "10000원"
#       },
#       {
#         "name": "햄버거",
#         "price": "8000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 76,
#     "contact": {
#       "phone": "018-119-2464",
#       "email": "eungyeong75@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.yuhanhoesa.com/",
#     "reviews": [
#       {
#         "author": "김종수",
#         "date": "2024-01-17",
#         "rating": 4.873602023788014,
#         "comment": "Dolorum facere incidunt."
#       },
#       {
#         "author": "이민서",
#         "date": "2024-02-25",
#         "rating": 3.84522845518962,
#         "comment": "Culpa recusandae est voluptate ab occaecati."
#       },
#       {
#         "author": "김옥순",
#         "date": "2024-01-26",
#         "rating": 3.9662027037299126,
#         "comment": "Porro suscipit odio omnis qui corrupti."
#       }
#     ]
#   },
#   {
#     "id": "23",
#     "name": "김조이 양식",
#     "location": "충청북도 금산군 영동대004로",
#     "priceRange": "고가",
#     "rating": 2.3,
#     "menus": [
#       {
#         "name": "파스타",
#         "price": "12000원"
#       },
#       {
#         "name": "스테이크",
#         "price": "20000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 34,
#     "contact": {
#       "phone": "041-580-6705",
#       "email": "gimsumin@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.gimbag.net/",
#     "reviews": [
#       {
#         "author": "이영미",
#         "date": "2024-01-17",
#         "rating": 4.38352646216903,
#         "comment": "Odio dolorum eligendi aliquam quidem totam."
#       },
#       {
#         "author": "김숙자",
#         "date": "2024-03-25",
#         "rating": 4.892117949435867,
#         "comment": "Optio harum maiores molestiae inventore."
#       }
#     ]
#   },
#   {
#     "id": "24",
#     "name": "박최 중식",
#     "location": "대전광역시 서구 강남대거리",
#     "priceRange": "최고가",
#     "rating": 3.5,
#     "menus": [
#       {
#         "name": "탕수육",
#         "price": "15000원"
#       },
#       {
#         "name": "짜장면",
#         "price": "5000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 95,
#     "contact": {
#       "phone": "054-187-0224",
#       "email": "dgim@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.icoe.com/",
#     "reviews": [
#       {
#         "author": "이예은",
#         "date": "2024-04-13",
#         "rating": 4.669788371147844,
#         "comment": "Minima voluptatibus reiciendis."
#       },
#       {
#         "author": "류진우",
#         "date": "2024-02-26",
#         "rating": 4.320146439791415,
#         "comment": "Hic itaque nam exercitationem aliquid vero."
#       },
#       {
#         "author": "이정호",
#         "date": "2024-03-06",
#         "rating": 3.6961633622784253,
#         "comment": "Harum dicta tenetur adipisci velit ut harum."
#       },
#       {
#         "author": "서영자",
#         "date": "2024-01-09",
#         "rating": 3.160266542614594,
#         "comment": "Voluptatibus atque distinctio rerum aspernatur."
#       },
#       {
#         "author": "윤현지",
#         "date": "2024-01-29",
#         "rating": 3.04168558546252,
#         "comment": "Dolor veritatis ea et similique."
#       }
#     ]
#   },
#   {
#     "id": "25",
#     "name": "(주) 이이박 아시아음식",
#     "location": "경기도 안양시 동안구 백제고분559길 (하윤김이리)",
#     "priceRange": "저가",
#     "rating": 5.0,
#     "menus": [
#       {
#         "name": "샤오롱바오",
#         "price": "8000원"
#       },
#       {
#         "name": "팟타이",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 52,
#     "contact": {
#       "phone": "031-070-6910",
#       "email": "hyeonu86@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.coehangim.com/",
#     "reviews": [
#       {
#         "author": "김재현",
#         "date": "2024-04-01",
#         "rating": 4.394693355816714,
#         "comment": "Enim voluptatum provident sed."
#       },
#       {
#         "author": "박준영",
#         "date": "2024-04-23",
#         "rating": 3.506872134486801,
#         "comment": "Eligendi repellat architecto."
#       }
#     ]
#   },
#   {
#     "id": "26",
#     "name": "주식회사 정 프랑스식",
#     "location": "충청북도 천안시 동남구 봉은사1거리",
#     "priceRange": "최저가",
#     "rating": 1.0,
#     "menus": [
#       {
#         "name": "라따뚜이",
#         "price": "16000원"
#       },
#       {
#         "name": "부야베스",
#         "price": "22000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 53,
#     "contact": {
#       "phone": "053-987-8944",
#       "email": "borambag@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://yuhanhoesa.kr/",
#     "reviews": [
#       {
#         "author": "김준서",
#         "date": "2024-01-24",
#         "rating": 4.334513829784676,
#         "comment": "Culpa nihil necessitatibus quis corrupti."
#       },
#       {
#         "author": "서영미",
#         "date": "2024-01-12",
#         "rating": 4.420120039813373,
#         "comment": "Porro quam voluptate ut quaerat."
#       }
#     ]
#   },
#   {
#     "id": "27",
#     "name": "유한회사 강 아메리칸 음식",
#     "location": "서울특별시 강서구 봉은사길 (예진김조마을)",
#     "priceRange": "저가",
#     "rating": 3.9,
#     "menus": [
#       {
#         "name": "콥 샐러드",
#         "price": "9000원"
#       },
#       {
#         "name": "클램 차우더",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 80,
#     "contact": {
#       "phone": "018-376-1177",
#       "email": "heominseo@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.ju.com/",
#     "reviews": [
#       {
#         "author": "김영철",
#         "date": "2024-02-24",
#         "rating": 4.601501612063565,
#         "comment": "Blanditiis pariatur consequuntur beatae vero in voluptate."
#       },
#       {
#         "author": "이상철",
#         "date": "2024-04-28",
#         "rating": 4.596990646407297,
#         "comment": "Ipsam dolorum et."
#       }
#     ]
#   },
#   {
#     "id": "28",
#     "name": "송김김 한식",
#     "location": "인천광역시 영등포구 테헤란가 (상훈박김리)",
#     "priceRange": "중간",
#     "rating": 3.9,
#     "menus": [
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       },
#       {
#         "name": "된장찌개",
#         "price": "7000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 52,
#     "contact": {
#       "phone": "032-588-8165",
#       "email": "hayun66@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.coeiryu.com/",
#     "reviews": [
#       {
#         "author": "박예진",
#         "date": "2024-01-08",
#         "rating": 4.2221879294976645,
#         "comment": "Commodi tenetur culpa architecto unde repellat in."
#       }
#     ]
#   },
#   {
#     "id": "29",
#     "name": "(주) 안박김 일식",
#     "location": "세종특별자치시 서구 석촌호수가",
#     "priceRange": "고가",
#     "rating": 3.4,
#     "menus": [
#       {
#         "name": "라멘",
#         "price": "12000원"
#       },
#       {
#         "name": "돈부리",
#         "price": "11000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 93,
#     "contact": {
#       "phone": "042-155-0557",
#       "email": "junhyeoggim@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.ju.com/",
#     "reviews": [
#       {
#         "author": "최정호",
#         "date": "2024-02-11",
#         "rating": 3.6276722512716715,
#         "comment": "Nulla amet delectus deserunt nihil labore in."
#       },
#       {
#         "author": "김미경",
#         "date": "2024-01-11",
#         "rating": 3.497504043063664,
#         "comment": "Iste accusamus voluptatum vero."
#       },
#       {
#         "author": "허서영",
#         "date": "2024-01-23",
#         "rating": 3.968255831729029,
#         "comment": "Dolorum labore a eligendi quisquam."
#       }
#     ]
#   },
#   {
#     "id": "30",
#     "name": "김김 프랑스식",
#     "location": "충청남도 홍천군 역삼로",
#     "priceRange": "중간",
#     "rating": 1.4,
#     "menus": [
#       {
#         "name": "부야베스",
#         "price": "22000원"
#       },
#       {
#         "name": "라따뚜이",
#         "price": "16000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 57,
#     "contact": {
#       "phone": "041-692-0770",
#       "email": "jiasin@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://munbaeg.com/",
#     "reviews": [
#       {
#         "author": "이지연",
#         "date": "2024-02-15",
#         "rating": 4.935921886886508,
#         "comment": "Nam debitis quos quasi."
#       }
#     ]
#   },
#   {
#     "id": "31",
#     "name": "이김이 일식",
#     "location": "대전광역시 도봉구 논현1가 (지연조이마을)",
#     "priceRange": "최저가",
#     "rating": 1.8,
#     "menus": [
#       {
#         "name": "돈부리",
#         "price": "11000원"
#       },
#       {
#         "name": "사케동",
#         "price": "13000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 83,
#     "contact": {
#       "phone": "070-2986-2507",
#       "email": "hanjeonghyi@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://bagson.kr/",
#     "reviews": [
#       {
#         "author": "김정훈",
#         "date": "2024-03-31",
#         "rating": 4.924274889595421,
#         "comment": "Neque vel a vitae vitae."
#       },
#       {
#         "author": "이보람",
#         "date": "2024-04-28",
#         "rating": 3.186925500607834,
#         "comment": "Necessitatibus esse harum quisquam doloremque eum quibusdam eos."
#       },
#       {
#         "author": "송예원",
#         "date": "2024-02-26",
#         "rating": 3.406881950987769,
#         "comment": "Commodi tenetur placeat fugiat accusamus odit voluptates totam."
#       },
#       {
#         "author": "서영길",
#         "date": "2024-02-05",
#         "rating": 3.3487233905476685,
#         "comment": "Tempora dolorem delectus autem eius quibusdam non."
#       },
#       {
#         "author": "박현숙",
#         "date": "2024-03-12",
#         "rating": 3.6330082655301537,
#         "comment": "Unde voluptatum velit facere at sequi."
#       }
#     ]
#   },
#   {
#     "id": "32",
#     "name": "문허최 퓨전음식",
#     "location": "울산광역시 종로구 학동로 (은지박손마을)",
#     "priceRange": "최저가",
#     "rating": 3.4,
#     "menus": [
#       {
#         "name": "멕시칸 삼겹살",
#         "price": "15000원"
#       },
#       {
#         "name": "김치 파스타",
#         "price": "11000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 25,
#     "contact": {
#       "phone": "055-493-3775",
#       "email": "seongjin14@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://ju.kr/",
#     "reviews": [
#       {
#         "author": "김미경",
#         "date": "2024-02-17",
#         "rating": 4.451757467673012,
#         "comment": "Dolor ex dolore eius cupiditate."
#       },
#       {
#         "author": "이민수",
#         "date": "2024-03-26",
#         "rating": 3.273254887928572,
#         "comment": "Provident error voluptatum."
#       },
#       {
#         "author": "전영진",
#         "date": "2024-04-30",
#         "rating": 3.791503733794296,
#         "comment": "Ullam eligendi iusto quod."
#       },
#       {
#         "author": "박성민",
#         "date": "2024-03-19",
#         "rating": 3.6718878711088676,
#         "comment": "Distinctio magnam iste ducimus at."
#       },
#       {
#         "author": "박재현",
#         "date": "2024-01-23",
#         "rating": 3.5794328435019667,
#         "comment": "Neque delectus facere sapiente nemo eius placeat."
#       }
#     ]
#   },
#   {
#     "id": "33",
#     "name": "주식회사 김김양 아시아음식",
#     "location": "대전광역시 마포구 양재천9가",
#     "priceRange": "최고가",
#     "rating": 4.4,
#     "menus": [
#       {
#         "name": "팟타이",
#         "price": "12000원"
#       },
#       {
#         "name": "치킨 커리",
#         "price": "10000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 77,
#     "contact": {
#       "phone": "061-167-0516",
#       "email": "hyeonjunheo@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://igim.com/",
#     "reviews": [
#       {
#         "author": "양영길",
#         "date": "2024-04-12",
#         "rating": 4.310785321010299,
#         "comment": "Iste voluptates qui cum dolorum praesentium molestias."
#       }
#     ]
#   },
#   {
#     "id": "34",
#     "name": "(유) 한 프랑스식",
#     "location": "충청북도 양구군 언주43길 (진호김권마을)",
#     "priceRange": "최고가",
#     "rating": 5.0,
#     "menus": [
#       {
#         "name": "부야베스",
#         "price": "22000원"
#       },
#       {
#         "name": "에스카르고",
#         "price": "18000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 63,
#     "contact": {
#       "phone": "055-852-5640",
#       "email": "yeonghwani@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://yu.kr/",
#     "reviews": [
#       {
#         "author": "장승민",
#         "date": "2024-01-16",
#         "rating": 3.1579018622462076,
#         "comment": "Optio distinctio minus quasi."
#       },
#       {
#         "author": "손승민",
#         "date": "2024-01-20",
#         "rating": 4.589507062505405,
#         "comment": "Veniam distinctio nesciunt voluptatum."
#       },
#       {
#         "author": "최지현",
#         "date": "2024-04-20",
#         "rating": 3.590349774980128,
#         "comment": "Exercitationem delectus commodi totam corrupti."
#       },
#       {
#         "author": "박영진",
#         "date": "2024-02-17",
#         "rating": 3.6137488334142898,
#         "comment": "Nisi odit recusandae quod sapiente amet repellat."
#       }
#     ]
#   },
#   {
#     "id": "35",
#     "name": "이오 양식",
#     "location": "경상북도 음성군 논현로 (민석김고동)",
#     "priceRange": "최저가",
#     "rating": 3.3,
#     "menus": [
#       {
#         "name": "햄버거",
#         "price": "8000원"
#       },
#       {
#         "name": "리조또",
#         "price": "10000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 17,
#     "contact": {
#       "phone": "018-670-5993",
#       "email": "gimsunog@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.yuhanhoesa.com/",
#     "reviews": [
#       {
#         "author": "손영일",
#         "date": "2024-01-09",
#         "rating": 4.408786364451881,
#         "comment": "Recusandae ducimus dolor modi magnam."
#       }
#     ]
#   },
#   {
#     "id": "36",
#     "name": "최이 프랑스식",
#     "location": "충청북도 동두천시 서초중앙21가 (지후박읍)",
#     "priceRange": "저가",
#     "rating": 3.1,
#     "menus": [
#       {
#         "name": "크림 브륄레",
#         "price": "9000원"
#       },
#       {
#         "name": "라따뚜이",
#         "price": "16000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 58,
#     "contact": {
#       "phone": "011-944-6981",
#       "email": "sheo@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.yunryuhong.com/",
#     "reviews": [
#       {
#         "author": "진진우",
#         "date": "2024-02-02",
#         "rating": 4.151129476866879,
#         "comment": "Quisquam eveniet numquam quisquam vel minus reprehenderit quibusdam."
#       },
#       {
#         "author": "김민서",
#         "date": "2024-03-23",
#         "rating": 4.59502488051373,
#         "comment": "Doloremque explicabo molestiae blanditiis."
#       },
#       {
#         "author": "이성현",
#         "date": "2024-02-09",
#         "rating": 3.833802394561955,
#         "comment": "Ex sapiente tempore perspiciatis nesciunt recusandae ratione."
#       }
#     ]
#   },
#   {
#     "id": "37",
#     "name": "김김이 이탈리아 음식",
#     "location": "경상남도 속초시 강남대거리",
#     "priceRange": "중간",
#     "rating": 4.5,
#     "menus": [
#       {
#         "name": "티라미수",
#         "price": "7000원"
#       },
#       {
#         "name": "마르게리타 피자",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 60,
#     "contact": {
#       "phone": "017-949-1946",
#       "email": "jungsu64@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.yu.com/",
#     "reviews": [
#       {
#         "author": "강재현",
#         "date": "2024-01-23",
#         "rating": 3.6577070572582224,
#         "comment": "Voluptate eligendi eaque occaecati perferendis sapiente."
#       },
#       {
#         "author": "김윤서",
#         "date": "2024-02-23",
#         "rating": 4.896832911858658,
#         "comment": "Quaerat magnam animi ipsum culpa."
#       }
#     ]
#   },
#   {
#     "id": "38",
#     "name": "하손정 아메리칸 음식",
#     "location": "울산광역시 양천구 언주79거리",
#     "priceRange": "중간",
#     "rating": 1.8,
#     "menus": [
#       {
#         "name": "치즈버거",
#         "price": "10000원"
#       },
#       {
#         "name": "콥 샐러드",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 66,
#     "contact": {
#       "phone": "016-625-6741",
#       "email": "wcoe@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://gimnamha.com/",
#     "reviews": [
#       {
#         "author": "곽정자",
#         "date": "2024-04-19",
#         "rating": 4.865479499955948,
#         "comment": "Itaque illum dolore necessitatibus enim eligendi facilis."
#       },
#       {
#         "author": "백순옥",
#         "date": "2024-03-02",
#         "rating": 3.206881158177269,
#         "comment": "Laudantium vero fugit alias."
#       },
#       {
#         "author": "박경숙",
#         "date": "2024-01-04",
#         "rating": 4.571229567394168,
#         "comment": "Officia explicabo libero distinctio occaecati."
#       },
#       {
#         "author": "곽서영",
#         "date": "2024-01-28",
#         "rating": 4.5834117971752875,
#         "comment": "Reprehenderit esse perferendis dolore."
#       },
#       {
#         "author": "이영자",
#         "date": "2024-01-07",
#         "rating": 3.4065027273271555,
#         "comment": "Nemo excepturi rerum error."
#       }
#     ]
#   },
#   {
#     "id": "39",
#     "name": "유한회사 이 한식",
#     "location": "충청남도 구리시 양재천가",
#     "priceRange": "저가",
#     "rating": 4.3,
#     "menus": [
#       {
#         "name": "된장찌개",
#         "price": "7000원"
#       },
#       {
#         "name": "비빔밥",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 91,
#     "contact": {
#       "phone": "062-828-2915",
#       "email": "jeonghun47@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.ju.com/",
#     "reviews": [
#       {
#         "author": "강수빈",
#         "date": "2024-03-19",
#         "rating": 3.0311291846239747,
#         "comment": "Velit at dolore facere debitis sapiente in."
#       }
#     ]
#   },
#   {
#     "id": "40",
#     "name": "(주) 김박장 한식",
#     "location": "대전광역시 노원구 삼성290거리 (상훈강양마을)",
#     "priceRange": "중간",
#     "rating": 1.9,
#     "menus": [
#       {
#         "name": "갈비탕",
#         "price": "12000원"
#       },
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 36,
#     "contact": {
#       "phone": "064-782-7887",
#       "email": "yejun95@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://yuhanhoesa.org/",
#     "reviews": [
#       {
#         "author": "손성호",
#         "date": "2024-03-13",
#         "rating": 3.6575971987110463,
#         "comment": "Repellat placeat aliquam reprehenderit tempora aperiam neque."
#       },
#       {
#         "author": "서영진",
#         "date": "2024-01-13",
#         "rating": 4.143678535640675,
#         "comment": "Repudiandae dignissimos reprehenderit quisquam debitis."
#       },
#       {
#         "author": "허성민",
#         "date": "2024-04-26",
#         "rating": 4.101626161924154,
#         "comment": "Cumque consequatur minima voluptas velit amet."
#       },
#       {
#         "author": "김정희",
#         "date": "2024-01-24",
#         "rating": 3.260313558947243,
#         "comment": "Porro nulla in facere."
#       },
#       {
#         "author": "김현정",
#         "date": "2024-04-24",
#         "rating": 4.936453910266817,
#         "comment": "Ad nihil nisi sequi facilis commodi."
#       }
#     ]
#   },
#   {
#     "id": "41",
#     "name": "김이박 아메리칸 음식",
#     "location": "광주광역시 동대문구 오금1가",
#     "priceRange": "최고가",
#     "rating": 1.6,
#     "menus": [
#       {
#         "name": "콥 샐러드",
#         "price": "9000원"
#       },
#       {
#         "name": "클램 차우더",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 74,
#     "contact": {
#       "phone": "019-944-8543",
#       "email": "gimujin@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.ju.kr/",
#     "reviews": [
#       {
#         "author": "장재호",
#         "date": "2024-03-01",
#         "rating": 3.590257906548419,
#         "comment": "Accusamus dolores hic culpa qui enim non."
#       },
#       {
#         "author": "김하윤",
#         "date": "2024-03-25",
#         "rating": 4.712674659814867,
#         "comment": "Saepe est assumenda occaecati quidem fugiat."
#       },
#       {
#         "author": "김지민",
#         "date": "2024-04-07",
#         "rating": 4.430398053336924,
#         "comment": "Quidem quo saepe ratione omnis in ipsa."
#       },
#       {
#         "author": "김정호",
#         "date": "2024-03-04",
#         "rating": 4.772146418736181,
#         "comment": "Sint illum maxime asperiores iste facilis."
#       },
#       {
#         "author": "이미정",
#         "date": "2024-02-12",
#         "rating": 3.017047358117117,
#         "comment": "Ex consequuntur expedita laudantium enim error."
#       }
#     ]
#   },
#   {
#     "id": "42",
#     "name": "김김권 프랑스식",
#     "location": "경상남도 군포시 서초대거리",
#     "priceRange": "중간",
#     "rating": 4.7,
#     "menus": [
#       {
#         "name": "에스카르고",
#         "price": "18000원"
#       },
#       {
#         "name": "부야베스",
#         "price": "22000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 97,
#     "contact": {
#       "phone": "011-086-7809",
#       "email": "ugim@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.ju.com/",
#     "reviews": [
#       {
#         "author": "류경숙",
#         "date": "2024-01-04",
#         "rating": 4.118415949651636,
# ...
#         "rating": 3.478819264322175,
#         "comment": "Reprehenderit quas eaque nisi debitis impedit."
#       },
#       {
#         "author": "이미경",
#         "date": "2024-04-26",
#         "rating": 4.062836274454491,
#         "comment": "Quas laudantium vero laudantium consequuntur amet amet incidunt."
#       }
#     ]
#   },
#   {
#     "id": "88",
#     "name": "배남백 퓨전음식",
#     "location": "전라남도 단양군 오금9로 (병철윤이마을)",
#     "priceRange": "최저가",
#     "rating": 4.5,
#     "menus": [
#       {
#         "name": "김치 파스타",
#         "price": "11000원"
#       },
#       {
#         "name": "멕시칸 삼겹살",
#         "price": "15000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 55,
#     "contact": {
#       "phone": "055-244-8067",
#       "email": "ljang@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://jusighoesa.com/",
#     "reviews": [
#       {
#         "author": "하보람",
#         "date": "2024-02-12",
#         "rating": 3.0903627098692663,
#         "comment": "Dolorem aut repudiandae deserunt neque."
#       },
#       {
#         "author": "민지훈",
#         "date": "2024-01-09",
#         "rating": 4.416983101878355,
#         "comment": "Iste magnam molestiae nemo minus fugiat."
#       },
#       {
#         "author": "김은정",
#         "date": "2024-04-07",
#         "rating": 3.793637425954374,
#         "comment": "Debitis optio cumque ducimus fugit quasi."
#       },
#       {
#         "author": "박명숙",
#         "date": "2024-02-20",
#         "rating": 4.1020042253486935,
#         "comment": "Atque dolor eius sapiente."
#       }
#     ]
#   },
#   {
#     "id": "89",
#     "name": "이고 한식",
#     "location": "충청남도 양양군 테헤란거리 (은서김읍)",
#     "priceRange": "중간",
#     "rating": 1.6,
#     "menus": [
#       {
#         "name": "갈비탕",
#         "price": "12000원"
#       },
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 49,
#     "contact": {
#       "phone": "011-953-9558",
#       "email": "hyeonjeong89@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.bagsong.com/",
#     "reviews": [
#       {
#         "author": "황상호",
#         "date": "2024-04-14",
#         "rating": 4.266755831795173,
#         "comment": "Aut impedit laudantium distinctio quas amet."
#       },
#       {
#         "author": "허하은",
#         "date": "2024-02-04",
#         "rating": 4.104709949225047,
#         "comment": "Quae ipsa aperiam accusamus aperiam nulla voluptate."
#       }
#     ]
#   },
#   {
#     "id": "90",
#     "name": "(주) 김 일식",
#     "location": "인천광역시 강남구 역삼008가",
#     "priceRange": "최저가",
#     "rating": 2.5,
#     "menus": [
#       {
#         "name": "돈부리",
#         "price": "11000원"
#       },
#       {
#         "name": "라멘",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 41,
#     "contact": {
#       "phone": "031-843-1863",
#       "email": "seongsu71@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.yuhanhoesa.com/",
#     "reviews": [
#       {
#         "author": "백영미",
#         "date": "2024-03-16",
#         "rating": 4.897092044960406,
#         "comment": "Sapiente molestiae modi omnis aspernatur nesciunt perferendis asperiores."
#       },
#       {
#         "author": "박준영",
#         "date": "2024-02-25",
#         "rating": 3.040091533448573,
#         "comment": "Molestiae corporis possimus ullam."
#       },
#       {
#         "author": "이민수",
#         "date": "2024-01-17",
#         "rating": 3.9338478339896703,
#         "comment": "Dignissimos necessitatibus eaque placeat ipsam iusto."
#       },
#       {
#         "author": "오예진",
#         "date": "2024-05-01",
#         "rating": 3.9343756368420837,
#         "comment": "Architecto ea dolorum ratione odio nam autem."
#       },
#       {
#         "author": "오순자",
#         "date": "2024-03-23",
#         "rating": 3.273453013036017,
#         "comment": "Ipsum voluptate iusto fuga."
#       }
#     ]
#   },
#   {
#     "id": "91",
#     "name": "김김 한식",
#     "location": "대구광역시 강북구 논현04거리",
#     "priceRange": "중간",
#     "rating": 1.7,
#     "menus": [
#       {
#         "name": "된장찌개",
#         "price": "7000원"
#       },
#       {
#         "name": "갈비탕",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "배달 가능"
#     ],
#     "seatingCapacity": 97,
#     "contact": {
#       "phone": "033-105-6660",
#       "email": "donghyeon56@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.bagi.com/",
#     "reviews": [
#       {
#         "author": "박영길",
#         "date": "2024-03-25",
#         "rating": 3.9207117114110037,
#         "comment": "Ad reprehenderit molestiae adipisci sunt consequatur."
#       },
#       {
#         "author": "김성민",
#         "date": "2024-04-11",
#         "rating": 4.965154811760181,
#         "comment": "Natus iusto perferendis."
#       },
#       {
#         "author": "이예준",
#         "date": "2024-02-23",
#         "rating": 4.65639292887831,
#         "comment": "Totam necessitatibus in repellat illo minus repudiandae."
#       },
#       {
#         "author": "진상훈",
#         "date": "2024-05-01",
#         "rating": 3.0700497050720132,
#         "comment": "Soluta accusamus atque ut rerum accusamus molestias at."
#       }
#     ]
#   },
#   {
#     "id": "92",
#     "name": "김최이 프랑스식",
#     "location": "부산광역시 영등포구 가락62길 (춘자윤김동)",
#     "priceRange": "저가",
#     "rating": 3.7,
#     "menus": [
#       {
#         "name": "부야베스",
#         "price": "22000원"
#       },
#       {
#         "name": "에스카르고",
#         "price": "18000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 85,
#     "contact": {
#       "phone": "061-960-3633",
#       "email": "cgang@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.yu.net/",
#     "reviews": [
#       {
#         "author": "최민석",
#         "date": "2024-04-02",
#         "rating": 4.499322357385953,
#         "comment": "Cum temporibus ipsum incidunt illo in impedit aliquid."
#       },
#       {
#         "author": "양정웅",
#         "date": "2024-01-15",
#         "rating": 3.921055141480144,
#         "comment": "Iusto dolorum maxime veritatis aliquid eaque maiores."
#       },
#       {
#         "author": "이영순",
#         "date": "2024-03-03",
#         "rating": 4.8564396495593884,
#         "comment": "Occaecati asperiores molestias vel."
#       }
#     ]
#   },
#   {
#     "id": "93",
#     "name": "유한회사 김박류 중식",
#     "location": "서울특별시 북구 압구정714로 (순자김리)",
#     "priceRange": "최저가",
#     "rating": 1.1,
#     "menus": [
#       {
#         "name": "탕수육",
#         "price": "15000원"
#       },
#       {
#         "name": "짜장면",
#         "price": "5000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "주차 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 22,
#     "contact": {
#       "phone": "055-885-8563",
#       "email": "cyun@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.yanggim.com/",
#     "reviews": [
#       {
#         "author": "조광수",
#         "date": "2024-03-18",
#         "rating": 3.052420961817688,
#         "comment": "Dignissimos commodi ut earum voluptates consequatur."
#       },
#       {
#         "author": "이은정",
#         "date": "2024-03-12",
#         "rating": 4.6989442563084864,
#         "comment": "Repudiandae maxime blanditiis totam reiciendis odio voluptatibus."
#       },
#       {
#         "author": "장미숙",
#         "date": "2024-04-12",
#         "rating": 3.4973913654693676,
#         "comment": "Eum quo dolorem sint deserunt et amet soluta."
#       },
#       {
#         "author": "김미경",
#         "date": "2024-04-02",
#         "rating": 3.861305067573123,
#         "comment": "Cum ipsum sapiente blanditiis iure libero eveniet."
#       },
#       {
#         "author": "신은정",
#         "date": "2024-03-17",
#         "rating": 3.050268047949327,
#         "comment": "Vero quo ad sapiente beatae sit aut ex."
#       }
#     ]
#   },
#   {
#     "id": "94",
#     "name": "(유) 이 한식",
#     "location": "인천광역시 강동구 가락로",
#     "priceRange": "고가",
#     "rating": 4.8,
#     "menus": [
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       },
#       {
#         "name": "갈비탕",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 36,
#     "contact": {
#       "phone": "017-989-3340",
#       "email": "ajeon@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://ijingim.org/",
#     "reviews": [
#       {
#         "author": "최서준",
#         "date": "2024-02-14",
#         "rating": 4.448511404343392,
#         "comment": "Repudiandae omnis recusandae esse aliquid recusandae."
#       },
#       {
#         "author": "김광수",
#         "date": "2024-03-12",
#         "rating": 3.6234793485348042,
#         "comment": "Saepe doloribus tempora eum."
#       },
#       {
#         "author": "이민지",
#         "date": "2024-02-08",
#         "rating": 3.9407801375741354,
#         "comment": "Id deserunt sapiente fugit cupiditate rem."
#       },
#       {
#         "author": "김영자",
#         "date": "2024-01-06",
#         "rating": 3.710222163993156,
#         "comment": "Aliquid dolores corporis pariatur reprehenderit atque."
#       },
#       {
#         "author": "이하은",
#         "date": "2024-02-07",
#         "rating": 4.395494833523879,
#         "comment": "Aut quisquam commodi officia non."
#       }
#     ]
#   },
#   {
#     "id": "95",
#     "name": "오김박 한식",
#     "location": "울산광역시 은평구 석촌호수로 (상훈이이면)",
#     "priceRange": "최저가",
#     "rating": 4.1,
#     "menus": [
#       {
#         "name": "된장찌개",
#         "price": "7000원"
#       },
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "포장 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 97,
#     "contact": {
#       "phone": "02-6302-7247",
#       "email": "sunjana@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://gimhwanghwang.com/",
#     "reviews": [
#       {
#         "author": "양상호",
#         "date": "2024-03-02",
#         "rating": 4.682534209344574,
#         "comment": "Voluptates quo beatae quaerat tempora hic."
#       }
#     ]
#   },
#   {
#     "id": "96",
#     "name": "(주) 이 한식",
#     "location": "경상북도 수원시 팔달구 강남대12길 (예진차리)",
#     "priceRange": "최저가",
#     "rating": 3.5,
#     "menus": [
#       {
#         "name": "김치찌개",
#         "price": "8000원"
#       },
#       {
#         "name": "비빔밥",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "주차 가능"
#     ],
#     "seatingCapacity": 42,
#     "contact": {
#       "phone": "052-383-0368",
#       "email": "jgwag@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://www.yuhanhoesa.kr/",
#     "reviews": [
#       {
#         "author": "심우진",
#         "date": "2024-02-28",
#         "rating": 4.39801488062117,
#         "comment": "Earum amet omnis eius voluptate deleniti eius possimus."
#       }
#     ]
#   },
#   {
#     "id": "97",
#     "name": "박김 퓨전음식",
#     "location": "강원도 서천군 테헤란738로 (준호김읍)",
#     "priceRange": "중간",
#     "rating": 3.7,
#     "menus": [
#       {
#         "name": "커리 우동",
#         "price": "9000원"
#       },
#       {
#         "name": "김치 파스타",
#         "price": "11000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 68,
#     "contact": {
#       "phone": "052-341-2591",
#       "email": "xmun@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "http://anica.com/",
#     "reviews": [
#       {
#         "author": "이수빈",
#         "date": "2024-04-16",
#         "rating": 4.064514398180653,
#         "comment": "Fugiat tenetur nihil ipsam."
#       },
#       {
#         "author": "이경수",
#         "date": "2024-04-30",
#         "rating": 4.286093530593925,
#         "comment": "Ea odio voluptates eligendi fugiat optio."
#       },
#       {
#         "author": "이병철",
#         "date": "2024-01-28",
#         "rating": 3.14884621426145,
#         "comment": "Neque iste quaerat quas vero temporibus mollitia."
#       },
#       {
#         "author": "김민재",
#         "date": "2024-04-29",
#         "rating": 4.428894343130085,
#         "comment": "Reiciendis voluptas accusantium asperiores sint corporis adipisci."
#       }
#     ]
#   },
#   {
#     "id": "98",
#     "name": "유한회사 김송한 이탈리아 음식",
#     "location": "전라남도 안산시 상록구 압구정2거리",
#     "priceRange": "고가",
#     "rating": 4.0,
#     "menus": [
#       {
#         "name": "페투치니 알프레도",
#         "price": "13500원"
#       },
#       {
#         "name": "티라미수",
#         "price": "7000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 62,
#     "contact": {
#       "phone": "061-435-2201",
#       "email": "ggim@example.net"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.igim.kr/",
#     "reviews": [
#       {
#         "author": "성예은",
#         "date": "2024-01-22",
#         "rating": 3.706284803137809,
#         "comment": "Nam ducimus vero vel facere sunt blanditiis."
#       }
#     ]
#   },
#   {
#     "id": "99",
#     "name": "유한회사 김최김 퓨전음식",
#     "location": "경상남도 공주시 가락길 (시우윤마을)",
#     "priceRange": "최고가",
#     "rating": 3.4,
#     "menus": [
#       {
#         "name": "김치 파스타",
#         "price": "11000원"
#       },
#       {
#         "name": "커리 우동",
#         "price": "9000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "예약 가능",
#       "포장 가능"
#     ],
#     "seatingCapacity": 49,
#     "contact": {
#       "phone": "02-7283-9924",
#       "email": "jihu09@example.org"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.jusighoesa.kr/",
#     "reviews": [
#       {
#         "author": "심영희",
#         "date": "2024-02-07",
#         "rating": 3.8380223742744564,
#         "comment": "Modi accusamus molestias."
#       },
#       {
#         "author": "김승현",
#         "date": "2024-02-14",
#         "rating": 4.697802081853384,
#         "comment": "Cum quis nemo nam nobis ullam atque."
#       },
#       {
#         "author": "김중수",
#         "date": "2024-02-04",
#         "rating": 4.69983021130924,
#         "comment": "Deleniti quibusdam deleniti aspernatur."
#       }
#     ]
#   },
#   {
#     "id": "100",
#     "name": "(주) 장 양식",
#     "location": "전라남도 가평군 영동대637거리",
#     "priceRange": "저가",
#     "rating": 4.4,
#     "menus": [
#       {
#         "name": "햄버거",
#         "price": "8000원"
#       },
#       {
#         "name": "파스타",
#         "price": "12000원"
#       }
#     ],
#     "businessHours": "오전 10시 - 오후 10시",
#     "reservations": [],
#     "additionalServices": [
#       "배달 가능",
#       "예약 가능"
#     ],
#     "seatingCapacity": 88,
#     "contact": {
#       "phone": "02-0520-6147",
#       "email": "yeongsun63@example.com"
#     },
#     "specialNotes": "주말에는 예약이 필요할 수 있습니다.",
#     "website": "https://www.heobaegim.kr/",
#     "reviews": [
#       {
#         "author": "신현우",
#         "date": "2024-01-02",
#         "rating": 4.685833570209841,
#         "comment": "Eius in occaecati."
#       },
#       {
#         "author": "권지후",
#         "date": "2024-02-13",
#         "rating": 4.6935367623320605,
#         "comment": "Sint autem magni veniam magni ea."
#       },
#       {
#         "author": "김현준",
#         "date": "2024-02-09",
#         "rating": 3.1526837616970678,
#         "comment": "Repudiandae doloremque ducimus officiis."
#       },
#       {
#         "author": "김지혜",
#         "date": "2024-02-26",
#         "rating": 3.4710955447121012,
#         "comment": "Suscipit corrupti quod exercitationem."
#       }
#     ]
#   }
# ]
